# %%
import pandas as pd
import numpy as np
import plotly.plotly as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import seaborn

# %%
# %matplotlib inline

# %%
df=pd.read_csv("C:/Users/ss5399/Desktop/New Folder/NAS.csv", low_memory = False)
data = df[['Time','Downlink PDU Rate','Uplink PDU Rate']]

# %%
plt.scatter(data["Uplink PDU Rate"], data["Downlink PDU Rate"])

# %%
dpdu = data[["Time" ,"Downlink PDU Rate"]]
dpdu
# Out:
#                Time  Downlink PDU Rate
# 0      23:47:20:707                  0
# 1      23:47:21:207                  0
# 2      23:47:21:707                  0
# 3      23:47:22:207                  0
# 4      23:47:22:707                  0
# 5      23:47:23:207                  0
# 6      23:47:23:707                  0
# 7      23:47:24:207                  0
# 8      23:47:24:707                  0
# 9      23:47:25:207                  0
# 10     23:47:25:707                  0
# 11     23:47:26:207                  0
# 12     23:47:26:707                  0
# 13     23:47:27:207                  0
# 14     23:47:27:707                  0
# 15     23:47:28:207                  0
# 16     23:47:28:707                  0
# 17     23:47:29:207                  0
# 18     23:47:29:707                  0
# 19     23:47:30:207                  0
# 20     23:47:30:707                  0
# 21     23:47:31:207                  0
# 22     23:47:31:707                  0
# ...

# %%
dpdux = dpdu[dpdu["Downlink PDU Rate"] != 0]
dpdux
# Out:
#                Time  Downlink PDU Rate
# 140    23:48:30:707                  2
# 141    23:48:31:207                 10
# 142    23:48:31:707                  2
# 143    23:48:32:207                 10
# 145    23:48:33:207                 12
# 147    23:48:34:207                 12
# 148    23:48:34:707                  2
# 149    23:48:35:207                 10
# 150    23:48:35:707                  2
# 151    23:48:36:207                  4
# 152    23:48:36:707                  2
# 153    23:48:37:207                 10
# 154    23:48:37:707                  2
# 155    23:48:38:207                 10
# 156    23:48:38:707                  2
# 157    23:48:39:207                 16
# 158    23:48:39:707                  2
# 159    23:48:40:207                 10
# 160    23:48:40:707                  2
# 161    23:48:41:207                 10
# 162    23:48:41:707                  2
# 163    23:48:42:207                 10
# 164    23:48:42:707                  2
# ...

# %%
seaborn.distplot(dpdux["Downlink PDU Rate"], bins=10)

# %%
i = 0
for cell in dpdu["Time"]:
    cell = cell.replace(":","")
    dpdu.loc[i,"TimeNew"] = cell
    i = i+1

# %%
dpdu = dpdu[dpdu["Downlink PDU Rate"] != 0]

# %%
plt.scatter(dpdu["TimeNew"].astype(int), dpdu["Downlink PDU Rate"])

# %%
my_plot = dpdux.plot(kind='line')
